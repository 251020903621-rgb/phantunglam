# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903621-rgb/phantunglam/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 100
print(x)
# Out:
# 100

# %%
saving = 1000
factor = 1.1
result = saving * factor**15
print(result)
# Out:
# 4177.248169415656

# %%
desc = "Data Science"
profitable = True

# %%
print(type(saving))

print(type(factor))

print(type(desc))

print(type(profitable))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
year1 = saving * factor
print(type(year1))


doubledesc = desc * 2
print(doubledesc)
# Out:
# <class 'float'>
# Data ScienceData Science

# %%
print("ngan hang tra toi $" + str(saving) + ", sau 15 nam toi da co $" + str(result) + ". Tuyet voi!")
pi_string = "3.1415926"
pi_float = float(pi_string)
# Out:
# ngan hang tra toi $1000, sau 15 nam toi da co $4177.248169415656. Tuyet voi!

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "living room", liv, bed, "bathroom", bath]
print(areas)
# Out:
# [11.25, 18.0, 'living room', 20.0, 10.75, 'bathroom', 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house =[["hallway", hall],
        ["kitchen", kit],
        ["living room", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
# Out:
# 11.25
# 9.5
# 20.0

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_areas= areas[3] + areas[-3]
print(eat_sleep_areas)
# Out:
# 28.75

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']
