# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903621-rgb/phantunglam/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số n: "))

tong = 0
for i in range(0, n+1):   # vòng lặp for chạy từ 0 đến n
    tong += i             # mỗi lần lặp cộng i vào biến tong

print("Tổng từ 0 đến", n, "là:", tong)

# %%
import math

a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
c = float(input("Nhập c: "))

if a == 0:
    # Nếu a = 0 thì phương trình trở thành bậc nhất
    if b == 0:
        if c == 0:
            print("Phương trình có vô số nghiệm")
        else:
            print("Phương trình vô nghiệm")
    else:
        x = -c / b
        print("Phương trình có nghiệm duy nhất x =", x)
else:  # else ở đây nghĩa là a ≠ 0
    delta = b**2 - 4*a*c
    if delta < 0:
        print("Phương trình vô nghiệm thực")
    elif delta == 0:
        x = -b / (2*a)
        print("Phương trình có nghiệm kép x =", x)
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print("Phương trình có 2 nghiệm phân biệt:")
        print("x1 =", x1)
        print("x2 =", x2)
